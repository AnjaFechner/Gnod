# %%
import pandas as pd

# %%
bill100=pd.read_csv('billboard_100.csv')
spotify=pd.read_csv('spotify.csv')

# %%
while fav_song != "":
    fav_song = input("What is your favority song and press Enter?")
   
    if fav_song in bill100["song"]:
        print("The song is one of the Top 100.")
        
    elif fav_song in spotify["song"]:
        ("The song is part of the Top Morning songs.")
        
    else:
        print("Your input is not in our lists.")
        
    break
# Out:
# What is your favority song and press Enter?Rise
# Your input is not in our lists.

# %%
bill100.head()
# Out:
#                              song  \
# 0                         Rapstar
# 1             Leave The Door Open
# 2                         Peaches
# 3  Montero (Call Me By Your Name)
# 4                      Levitating
#
#                                           artists
# 0                                          Polo G
# 1        Silk Sonic (Bruno Mars & Anderson .Paak)
# 2  Justin Bieber Featuring Daniel Caesar & Giveon
# 3                                       Lil Nas X
# 4                       Dua Lipa Featuring DaBaby

# %%
spotify.head()
# Out:
#                                           song           artists  \
# 0                                         Rise  Lost Frequencies
# 1                         Cover Me In Sunshine              P!nk
# 2                                        River       Tom Gregory
# 3                                       My 100             KIDDO
# 4  Too Late (feat. Wiz Khalifa & Lukas Graham)         Cash Cash
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.689   0.612    6    -6.014     1       0.0387        0.2280
# 1         0.476   0.594    5    -6.879     1       0.1350        0.0599
# 2         0.701   0.621   10    -4.972     1       0.0556        0.0237
# 3         0.624   0.785    2    -4.961     1       0.0735        0.1090
# 4         0.552   0.740    2    -2.335     1       0.1240        0.0740
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000008    0.3680    0.461  122.076  audio_features
# ...
