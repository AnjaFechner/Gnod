# %% [markdown]
# # Libraries

# %%
from bs4 import BeautifulSoup
import requests
from time import sleep
import pandas as pd
from tqdm.notebook import tqdm

# %% [markdown]
# # The URL (single page)

# %%
url = "https://goldstandardsonglist.com/Pages_Sort_2a/Sort_2a.htm"

# %% [markdown]
# # Download html

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# # Work with html

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# - Find the songtitle

# %%
song = soup.select("td.table1column2 > p > span")
# Out:
# [<span style="font-weight: bold; font-family:Arial, sans-serif">Abilene</span>,
#  <span style="font-weight: bold; font-family:Arial, sans-serif">Above And Beyond
#  (The Call Of Love)</span>,
#  <span style="font-weight: bold; font-family:Arial, sans-serif">AC/DC Current</span>,
#  <span style="font-weight: bold; font-family:Arial, sans-serif">Acadian Driftwood</span>,
#  <span style="font-weight: bold; font-family:Arial, sans-serif">Ac-Cent-Tchu-Ate The
#  Positive</span>,
#  <span style="font-weight: bold; font-family:Arial, sans-serif">Accident In Paradise,
#  An</span>,
#  <span style="font-weight: bold; font-family:Arial, sans-serif">Ace Of Spades</span>,
#  <span style="font-weight: bold; font-family:Arial, sans-serif">Acid Tracks</span>,
#  <span style="font-weight: bold; font-family:Arial, sans-serif">Acperience</span>,
#  <span style="font-weight: bold; font-family:Arial, sans-serif">Acquiesce</span>,
# ...

# %% [markdown]
# - find the artists

# %%
artist = soup.select("td.table1column4 > p > span")
# Out:
# [<span style="font-family: 'Arial', sans-serif">Gibson, D., Loudermilk, J. D.,
#  Brown, L., &amp; Stanton, A.; REC:
#  George Hamilton IV</span>,
#  <span style="font-family: 'Arial', sans-serif">Howard, Harlan; REC:
#  Conway Twitty; George
#  Hamilton IV; Sonny James;
#  Rodney Crowell</span>,
#  <span style="font-family: 'Arial', sans-serif">Christian, C., Goodman, B., &amp;
#  Hampton, L.; REC: Charlie
#  Christian; Benny Goodman;
#  Roberto Columbo</span>,
#  <span style="font-family: 'Arial', sans-serif">Robertson, Robbie; REC: The
#  Band</span>,
#  <span style="font-family: 'Arial', sans-serif">Arlen, H., &amp; Mercer, J.; REC:
#  Bing Crosby &amp; the Andrews
#  Sisters; Ella Fitzgerald; Frank
#  Sinatra</span>,
#  <span style="font-family: 'Arial', sans-serif">Vath, S., &amp; Hildenbeutel, R.;
#  REC: Sven Vath</span>,
#  <span style="font-family: 'Arial', sans-serif">Lemmy, Clarke, E., &amp; Taylor,
#  P.; REC: Motorhead</span>,
# ...

# %% [markdown]
# - find the genre

# %%
genre = soup.select("td.table1column3 > p > span")
# Out:
# [<span style="font-family: 'Arial', sans-serif">Country/Bluegrass</span>,
#  <span style="font-family: 'Arial', sans-serif">Country/Bluegrass</span>,
#  <span style="font-family: 'Arial', sans-serif">Jazz</span>,
#  <span style="font-family: 'Arial', sans-serif">Folk/Roots</span>,
#  <span style="font-family: 'Arial', sans-serif">Swing</span>,
#  <span style="font-family: 'Arial', sans-serif">Dance/Electronica</span>,
#  <span style="font-family: 'Arial', sans-serif">Rock/Pop</span>,
#  <span style="font-family: 'Arial', sans-serif">Dance/Electronica</span>,
#  <span style="font-family: 'Arial', sans-serif">Dance/Electronica</span>,
#  <span style="font-family: 'Arial', sans-serif">Rock/Pop</span>,
#  <span style="font-family: 'Arial', sans-serif">Rock/Pop</span>,
#  <span style="font-family: 'Arial', sans-serif">Country/Bluegrass</span>,
#  <span style="font-family: 'Arial', sans-serif">Hip-Hop</span>,
#  <span style="font-family: 'Arial', sans-serif">R &amp; B/Soul</span>,
# ...

# %% [markdown]
# # Create Lists for songs, artists and genre

# %%
songs = []
artists = []
genres = []

len_song = len(song_lst)

for i in tqdm(range(len_song)):
    song.append(soup.select("span.chart-element__information__song")[i].text)
    artist.append(soup.select("span.chart-element__information__artist")[i].text)

# %%
wait_time = randint(1,5)
    sleep(wait_time)
